# %%
# Source Data
ipl_players = [
    {
        "id": 1,
        "name": "Virat Kohli",
        "team": "Royal Challengers Bangalore",
        "role": "Batsman",
        "age": 35,
        "matches": 237,
        "runs": 7263,
        "wickets": 4,
        "batting_style": "Right-hand bat",
        "bowling_style": "Right-arm medium"
    },
    {
        "id": 2,
        "name": "MS Dhoni",
        "team": "Chennai Super Kings",
        "role": "Wicket-Keeper Batsman",
        "age": 43,
        "matches": 250,
        "runs": 5082,
        "wickets": 0,
        "batting_style": "Right-hand bat",
        "bowling_style": None
    },
    {
        "id": 3,
        "name": "Rohit Sharma",
        "team": "Mumbai Indians",
        "role": "Batsman",
        "age": 38,
        "matches": 243,
        "runs": 6211,
        "wickets": 15,
        "batting_style": "Right-hand bat",
        "bowling_style": "Right-arm offbreak"
    },
    {
        "id": 4,
        "name": "David Warner",
        "team": "Delhi Capitals",
        "role": "Batsman",
        "age": 38,
        "matches": 176,
        "runs": 6397,
        "wickets": 0,
        "batting_style": "Left-hand bat",
        "bowling_style": "Right-arm legbreak"
    },
    {
        "id": 5,
        "name": "Sanju Samson",
        "team": "Rajasthan Royals",
        "role": "Wicket-Keeper Batsman",
        "age": 30,
        "matches": 152,
        "runs": 3888,
        "wickets": 0,
        "batting_style": "Right-hand bat",
        "bowling_style": None
    },
    {
        "id": 6,
        "name": "KL Rahul",
        "team": "Lucknow Super Giants",
        "role": "Batsman",
        "age": 33,
        "matches": 118,
        "runs": 4163,
        "wickets": 0,
        "batting_style": "Right-hand bat",
        "bowling_style": None
    },
    {
        "id": 7,
        "name": "Shubman Gill",
        "team": "Gujarat Titans",
        "role": "Batsman",
        "age": 26,
        "matches": 91,
        "runs": 2790,
        "wickets": 0,
        "batting_style": "Right-hand bat",
        "bowling_style": None
    },
    {
        "id": 8,
        "name": "Andre Russell",
        "team": "Kolkata Knight Riders",
        "role": "All-Rounder",
        "age": 37,
        "matches": 112,
        "runs": 2262,
        "wickets": 96,
        "batting_style": "Right-hand bat",
        "bowling_style": "Right-arm fast"
    },
    {
        "id": 9,
        "name": "Shikhar Dhawan",
        "team": "Punjab Kings",
        "role": "Batsman",
        "age": 39,
        "matches": 217,
        "runs": 6617,
        "wickets": 4,
        "batting_style": "Left-hand bat",
        "bowling_style": "Right-arm offbreak"
    },
    {
        "id": 10,
        "name": "Rishabh Pant",
        "team": "Delhi Capitals",
        "role": "Wicket-Keeper Batsman",
        "age": 28,
        "matches": 98,
        "runs": 2838,
        "wickets": 0,
        "batting_style": "Left-hand bat",
        "bowling_style": None
    }
]
# python program to filter players using team.

team_name = 'Delhi Capitals'

# Result - List of players who are in that team.

def filter_players(team_name):
    filtered_players = []

    for player in ipl_players:
        if (player['team'] == team_name):
            filtered_players.append(player)

    print(filtered_players)

filter_players(team_name)
# Out:
# [{'id': 4, 'name': 'David Warner', 'team': 'Delhi Capitals', 'role': 'Batsman', 'age': 38, 'matches': 176, 'runs': 6397, 'wickets': 0, 'batting_style': 'Left-hand bat', 'bowling_style': 'Right-arm legbreak'}, {'id': 10, 'name': 'Rishabh Pant', 'team': 'Delhi Capitals', 'role': 'Wicket-Keeper Batsman', 'age': 28, 'matches': 98, 'runs': 2838, 'wickets': 0, 'batting_style': 'Left-hand bat', 'bowling_style': None}]
